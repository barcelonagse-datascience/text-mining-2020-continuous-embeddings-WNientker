# %% [markdown]
# # Continuous Embeddings
#
# In this notebook we will explore some continuous embedding spaces for words and documents.
#
# After each video in this notebook is a small exercise. I really encourage you to try the exercise on your own. There are solutions in `solutions.py` that can help you see that you are on the right track and give you new ideas, but I urge you not to look at those until you have tried to solve the solution on your own. Implementation is good practice!

# %%
import matplotlib.pyplot as plt
from IPython.lib.display import YouTubeVideo

plt.rcParams['figure.figsize'] = [12, 6]

# %%
YouTubeVideo('V2PorP6oMLY', width=640,height=360)

# %%
docs = ['"I dont believe people who see ghosts", said Mannie, before spitting into the wind and riding his bike down the street at top speed. He then went home and ate peanut-butter and jelly sandwiches all day with big glasses of milk, which he loves. Mannie really liked ghosts and he often told his mother so. He believed he saw them everywhere and that they existed to help us.',

        'People see incredible things. One time I saw some people talking about things they were seeing, and those people were so much fun. They saw clouds and they saw airplanes and they saw Ghosts. Ghosts were the most incredible things people saw. ',
        
        'We have collected a report of people in our community seeing ghosts. Each resident was asked "how many ghosts have you seen?", "describe the last ghost you saw", and "tell us about your mother." Afterwards, we compared the ghost reports between the different individuals, and assessed whether or not they were actually seeing these apparitions.',

        'This is an article about a circus. A Circus is where people go to see other people who perform great things. Circuses also have elephants and tigers, which generally get a big woop from the crowd. People love the tigers.',

        'Goat milk is essential for strong bones. We recommend drinking much goat milk, people of all ages should drink goat milk. Tigers milk is also essential.',

        'Goats are lovely creatures. Many people love goats. People who love goats love seeing them play in the fields.',

        'There are many types of milk in the world, from elephants, cows, sheep, tiger, mothers, etc. Each of these milks are important for building strong bodies and healthy bones. ']

import re
import spacy
import seaborn as sns
import pandas as pd
import numpy as np
from nltk.stem.snowball import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

stemmer = SnowballStemmer("english")
not_alphanumeric_or_space = re.compile(r'[^(\w|\s|\d)]')
nlp = spacy.load('en_core_web_sm')

def preprocess(doc):
    doc = re.sub(not_alphanumeric_or_space, '', doc)
    words = [t.lemma_ for t in nlp(doc) if t.lemma_ != '-PRON-' and t.lemma_ != 'make']
    return ' '.join(words).lower()

vectorizer = TfidfVectorizer(min_df=2,
                             max_df=.8,
                             preprocessor=preprocess,
                             stop_words='english',
                             use_idf=False,
                             norm=False)

v = vectorizer.fit_transform(docs)
v = np.asarray(v.todense())

labels, _ = zip(*sorted(vectorizer.vocabulary_.items(), key=lambda x: x[1]))

def pca_loadings(v):
    pca = TruncatedSVD(2)
    pca.fit(v)
    return pca.components_.T

def plot_words(vecs, labels):
    df = pd.DataFrame(vecs).assign(labels = labels)
    ax = sns.scatterplot(x=0, y=1, data=df)
    for _, r in df.iterrows():
        ax.text(r[0] + 0.01 , r[1], r.labels)

word_vecs = pca_loadings(v)
plot_words(word_vecs, labels)

# %% [markdown]
# **Exercise 1**
#
# Create a document-term matrix from `docs` (this will probably be a copy-paste of code from last week!). Be fairly aggressive with your vocabulary pruning (feel free to look at the settings I use in the `solutions.py` for the vectorizer).
#
# Get the "loadings" matrix of the first 2 dimensions of PCA run on your document-term matrix. This is the $V^T$ from the SVD decomposition (HINT: this is the `.components_` of `sklearn` PCA models. Also, you can use `TruncatedSVD` to have a model that works on sparse matrices as well, even though its not needed in these toy examples).
#
# Plot the 2-dimensional word vectors in a scatter plot with labels for each word. What do you think of how they are laid out?

# %%
YouTubeVideo('zR01I04XP9A', width=640,height=360)

# %% [markdown]
# **Exercise 2**
#
# As per the video, learn an embedding matrix, $W$, such that $\sigma(XW\beta)$ predicts class y in our documents. Initialize the matrix $W$ with $V^T$ from the SVD decomposition of your document-term-frequency matrix $X$.
#
# Use `pytorch` to solve this problem. You don't need any neural network infrastructure, it's very simple with just matrix multiplication and gradients.
#
# Remember, this is just logistic regression in a latent space, and that latent space is defined by a linear mapping ($W$) that is learned at the same time as the coefficients of the logistic regression.
#
#
# [This tutorial in the pytorch documentation gives you what you need!](https://pytorch.org/tutorials/beginner/blitz/autograd_tutorial.html#sphx-glr-beginner-blitz-autograd-tutorial-py)
#
# I also encourage you to look at the solutions if you are new to `pytorch`, you will have another chance in a later exercise to play with it on your own!

# %%
conda install pytorch -c pytorch
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\woute\Anaconda3
#
#   added / updated specs:
#     - pytorch
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.4.5.1         |           py37_0         156 KB
#     cudatoolkit-10.2.89        |       h74a9793_1       317.2 MB
#     ninja-1.9.0                |   py37h74a9793_0         238 KB
#     openssl-1.1.1g             |       he774522_0         4.8 MB
#     pytorch-1.5.0              |py3.7_cuda102_cudnn7_0       559.9 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:       882.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        pkgs/main/win-64::cudatoolkit-10.2.89-h74a9793_1
#   ninja              pkgs/main/win-64::ninja-1.9.0-py37h74a9793_0
#   pytorch            pytorch/win-64::pytorch-1.5.0-py3.7_cuda102_cudnn7_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge::certifi-2020.4.5.1-py37h~ --> pkgs/main::certifi-2020.4.5.1-py37_0
#   openssl                                       conda-forge --> pkgs/main
#
#
#
# Downloading and Extracting Packages
#
# certifi-2020.4.5.1   | 156 KB    |            |   0%
# certifi-2020.4.5.1   | 156 KB    | #          |  10%
# certifi-2020.4.5.1   | 156 KB    | ########## | 100%
#
# pytorch-1.5.0        | 559.9 MB  |            |   0%
# pytorch-1.5.0        | 559.9 MB  |            |   0%
# pytorch-1.5.0        | 559.9 MB  |            |   0%
# pytorch-1.5.0        | 559.9 MB  |            |   0%
# pytorch-1.5.0        | 559.9 MB  |            |   0%
# pytorch-1.5.0        | 559.9 MB  |            |   0%
# pytorch-1.5.0        | 559.9 MB  |            |   0%
# pytorch-1.5.0        | 559.9 MB  |            |   0%
# pytorch-1.5.0        | 559.9 MB  |            |   0%
# pytorch-1.5.0        | 559.9 MB  |            |   1%
# pytorch-1.5.0        | 559.9 MB  |            |   1%
# pytorch-1.5.0        | 559.9 MB  | 1          |   1%
# pytorch-1.5.0        | 559.9 MB  | 1          |   1%
# pytorch-1.5.0        | 559.9 MB  | 1          |   2%
# pytorch-1.5.0        | 559.9 MB  | 1          |   2%
# pytorch-1.5.0        | 559.9 MB  | 2          |   2%
# pytorch-1.5.0        | 559.9 MB  | 2          |   3%
# pytorch-1.5.0        | 559.9 MB  | 3          |   3%
# pytorch-1.5.0        | 559.9 MB  | 3          |   4%
# pytorch-1.5.0        | 559.9 MB  | 3          |   4%
# pytorch-1.5.0        | 559.9 MB  | 4          |   4%
# pytorch-1.5.0        | 559.9 MB  | 4          |   5%
# pytorch-1.5.0        | 559.9 MB  | 4          |   5%
# pytorch-1.5.0        | 559.9 MB  | 5          |   5%
# pytorch-1.5.0        | 559.9 MB  | 5          |   5%
# pytorch-1.5.0        | 559.9 MB  | 5          |   6%
# pytorch-1.5.0        | 559.9 MB  | 5          |   6%
# pytorch-1.5.0        | 559.9 MB  | 6          |   6%
# pytorch-1.5.0        | 559.9 MB  | 6          |   6%
# pytorch-1.5.0        | 559.9 MB  | 7          |   7%
# pytorch-1.5.0        | 559.9 MB  | 7          |   7%
# pytorch-1.5.0        | 559.9 MB  | 7          |   8%
# pytorch-1.5.0        | 559.9 MB  | 8          |   8%
# pytorch-1.5.0        | 559.9 MB  | 8          |   8%
# pytorch-1.5.0        | 559.9 MB  | 8          |   9%
# pytorch-1.5.0        | 559.9 MB  | 8          |   9%
# pytorch-1.5.0        | 559.9 MB  | 9          |   9%
# pytorch-1.5.0        | 559.9 MB  | 9          |   9%
# pytorch-1.5.0        | 559.9 MB  | 9          |  10%
# pytorch-1.5.0        | 559.9 MB  | #          |  10%
# pytorch-1.5.0        | 559.9 MB  | #          |  10%
# pytorch-1.5.0        | 559.9 MB  | #          |  11%
# pytorch-1.5.0        | 559.9 MB  | #          |  11%
# pytorch-1.5.0        | 559.9 MB  | #1         |  11%
# pytorch-1.5.0        | 559.9 MB  | #1         |  11%
# pytorch-1.5.0        | 559.9 MB  | #1         |  12%
# pytorch-1.5.0        | 559.9 MB  | #1         |  12%
# pytorch-1.5.0        | 559.9 MB  | #2         |  12%
# pytorch-1.5.0        | 559.9 MB  | #2         |  12%
# pytorch-1.5.0        | 559.9 MB  | #2         |  13%
# pytorch-1.5.0        | 559.9 MB  | #2         |  13%
# pytorch-1.5.0        | 559.9 MB  | #3         |  13%
# pytorch-1.5.0        | 559.9 MB  | #3         |  13%
# pytorch-1.5.0        | 559.9 MB  | #3         |  14%
# pytorch-1.5.0        | 559.9 MB  | #3         |  14%
# pytorch-1.5.0        | 559.9 MB  | #4         |  14%
# pytorch-1.5.0        | 559.9 MB  | #4         |  14%
# pytorch-1.5.0        | 559.9 MB  | #4         |  15%
# pytorch-1.5.0        | 559.9 MB  | #4         |  15%
# pytorch-1.5.0        | 559.9 MB  | #5         |  15%
# pytorch-1.5.0        | 559.9 MB  | #5         |  15%
# pytorch-1.5.0        | 559.9 MB  | #5         |  16%
# pytorch-1.5.0        | 559.9 MB  | #5         |  16%
# pytorch-1.5.0        | 559.9 MB  | #6         |  16%
# pytorch-1.5.0        | 559.9 MB  | #6         |  16%
# pytorch-1.5.0        | 559.9 MB  | #6         |  17%
# pytorch-1.5.0        | 559.9 MB  | #6         |  17%
# pytorch-1.5.0        | 559.9 MB  | #7         |  17%
# pytorch-1.5.0        | 559.9 MB  | #7         |  17%
# pytorch-1.5.0        | 559.9 MB  | #7         |  18%
# pytorch-1.5.0        | 559.9 MB  | #7         |  18%
# pytorch-1.5.0        | 559.9 MB  | #8         |  18%
# pytorch-1.5.0        | 559.9 MB  | #8         |  18%
# pytorch-1.5.0        | 559.9 MB  | #8         |  19%
# pytorch-1.5.0        | 559.9 MB  | #8         |  19%
# pytorch-1.5.0        | 559.9 MB  | #9         |  19%
# pytorch-1.5.0        | 559.9 MB  | #9         |  19%
# pytorch-1.5.0        | 559.9 MB  | #9         |  20%
# pytorch-1.5.0        | 559.9 MB  | ##         |  20%
# pytorch-1.5.0        | 559.9 MB  | ##         |  20%
# pytorch-1.5.0        | 559.9 MB  | ##         |  21%
# pytorch-1.5.0        | 559.9 MB  | ##         |  21%
# pytorch-1.5.0        | 559.9 MB  | ##1        |  21%
# pytorch-1.5.0        | 559.9 MB  | ##1        |  21%
# pytorch-1.5.0        | 559.9 MB  | ##1        |  22%
# pytorch-1.5.0        | 559.9 MB  | ##1        |  22%
# pytorch-1.5.0        | 559.9 MB  | ##1        |  22%
# pytorch-1.5.0        | 559.9 MB  | ##2        |  22%
# pytorch-1.5.0        | 559.9 MB  | ##2        |  22%
# pytorch-1.5.0        | 559.9 MB  | ##2        |  23%
# pytorch-1.5.0        | 559.9 MB  | ##2        |  23%
# pytorch-1.5.0        | 559.9 MB  | ##3        |  23%
# pytorch-1.5.0        | 559.9 MB  | ##3        |  23%
# pytorch-1.5.0        | 559.9 MB  | ##3        |  24%
# pytorch-1.5.0        | 559.9 MB  | ##3        |  24%
# pytorch-1.5.0        | 559.9 MB  | ##4        |  24%
# pytorch-1.5.0        | 559.9 MB  | ##4        |  24%
# pytorch-1.5.0        | 559.9 MB  | ##4        |  25%
# pytorch-1.5.0        | 559.9 MB  | ##4        |  25%
# pytorch-1.5.0        | 559.9 MB  | ##5        |  25%
# pytorch-1.5.0        | 559.9 MB  | ##5        |  25%
# pytorch-1.5.0        | 559.9 MB  | ##5        |  26%
# pytorch-1.5.0        | 559.9 MB  | ##5        |  26%
# pytorch-1.5.0        | 559.9 MB  | ##6        |  26%
# pytorch-1.5.0        | 559.9 MB  | ##6        |  26%
# pytorch-1.5.0        | 559.9 MB  | ##6        |  27%
# pytorch-1.5.0        | 559.9 MB  | ##6        |  27%
# pytorch-1.5.0        | 559.9 MB  | ##7        |  27%
# pytorch-1.5.0        | 559.9 MB  | ##7        |  27%
# pytorch-1.5.0        | 559.9 MB  | ##7        |  28%
# pytorch-1.5.0        | 559.9 MB  | ##8        |  28%
# pytorch-1.5.0        | 559.9 MB  | ##8        |  28%
# pytorch-1.5.0        | 559.9 MB  | ##8        |  29%
# pytorch-1.5.0        | 559.9 MB  | ##8        |  29%
# pytorch-1.5.0        | 559.9 MB  | ##9        |  29%
# pytorch-1.5.0        | 559.9 MB  | ##9        |  29%
# pytorch-1.5.0        | 559.9 MB  | ##9        |  30%
# pytorch-1.5.0        | 559.9 MB  | ##9        |  30%
# pytorch-1.5.0        | 559.9 MB  | ###        |  30%
# pytorch-1.5.0        | 559.9 MB  | ###        |  30%
# pytorch-1.5.0        | 559.9 MB  | ###        |  31%
# pytorch-1.5.0        | 559.9 MB  | ###        |  31%
# pytorch-1.5.0        | 559.9 MB  | ###1       |  31%
# pytorch-1.5.0        | 559.9 MB  | ###1       |  31%
# pytorch-1.5.0        | 559.9 MB  | ###1       |  32%
# pytorch-1.5.0        | 559.9 MB  | ###1       |  32%
# pytorch-1.5.0        | 559.9 MB  | ###2       |  32%
# pytorch-1.5.0        | 559.9 MB  | ###2       |  32%
# pytorch-1.5.0        | 559.9 MB  | ###2       |  33%
# pytorch-1.5.0        | 559.9 MB  | ###2       |  33%
# pytorch-1.5.0        | 559.9 MB  | ###3       |  33%
# pytorch-1.5.0        | 559.9 MB  | ###3       |  33%
# pytorch-1.5.0        | 559.9 MB  | ###3       |  34%
# pytorch-1.5.0        | 559.9 MB  | ###3       |  34%
# pytorch-1.5.0        | 559.9 MB  | ###4       |  34%
# pytorch-1.5.0        | 559.9 MB  | ###4       |  34%
# pytorch-1.5.0        | 559.9 MB  | ###4       |  35%
# pytorch-1.5.0        | 559.9 MB  | ###4       |  35%
# pytorch-1.5.0        | 559.9 MB  | ###5       |  35%
# pytorch-1.5.0        | 559.9 MB  | ###5       |  35%
# pytorch-1.5.0        | 559.9 MB  | ###5       |  36%
# pytorch-1.5.0        | 559.9 MB  | ###5       |  36%
# pytorch-1.5.0        | 559.9 MB  | ###6       |  36%
# pytorch-1.5.0        | 559.9 MB  | ###6       |  36%
# pytorch-1.5.0        | 559.9 MB  | ###6       |  37%
# pytorch-1.5.0        | 559.9 MB  | ###7       |  37%
# pytorch-1.5.0        | 559.9 MB  | ###7       |  37%
# pytorch-1.5.0        | 559.9 MB  | ###7       |  38%
# pytorch-1.5.0        | 559.9 MB  | ###7       |  38%
# pytorch-1.5.0        | 559.9 MB  | ###8       |  38%
# pytorch-1.5.0        | 559.9 MB  | ###8       |  38%
# pytorch-1.5.0        | 559.9 MB  | ###8       |  39%
# pytorch-1.5.0        | 559.9 MB  | ###8       |  39%
# pytorch-1.5.0        | 559.9 MB  | ###9       |  39%
# pytorch-1.5.0        | 559.9 MB  | ###9       |  39%
# pytorch-1.5.0        | 559.9 MB  | ###9       |  40%
# pytorch-1.5.0        | 559.9 MB  | ###9       |  40%
# pytorch-1.5.0        | 559.9 MB  | ####       |  40%
# pytorch-1.5.0        | 559.9 MB  | ####       |  40%
# pytorch-1.5.0        | 559.9 MB  | ####       |  41%
# pytorch-1.5.0        | 559.9 MB  | ####       |  41%
# pytorch-1.5.0        | 559.9 MB  | ####1      |  41%
# pytorch-1.5.0        | 559.9 MB  | ####1      |  41%
# pytorch-1.5.0        | 559.9 MB  | ####1      |  42%
# pytorch-1.5.0        | 559.9 MB  | ####1      |  42%
# pytorch-1.5.0        | 559.9 MB  | ####2      |  42%
# pytorch-1.5.0        | 559.9 MB  | ####2      |  42%
# pytorch-1.5.0        | 559.9 MB  | ####2      |  43%
# pytorch-1.5.0        | 559.9 MB  | ####2      |  43%
# pytorch-1.5.0        | 559.9 MB  | ####3      |  43%
# pytorch-1.5.0        | 559.9 MB  | ####3      |  43%
# pytorch-1.5.0        | 559.9 MB  | ####3      |  44%
# pytorch-1.5.0        | 559.9 MB  | ####3      |  44%
# pytorch-1.5.0        | 559.9 MB  | ####4      |  44%
# pytorch-1.5.0        | 559.9 MB  | ####4      |  44%
# pytorch-1.5.0        | 559.9 MB  | ####4      |  45%
# pytorch-1.5.0        | 559.9 MB  | ####4      |  45%
# pytorch-1.5.0        | 559.9 MB  | ####5      |  45%
# pytorch-1.5.0        | 559.9 MB  | ####5      |  45%
# pytorch-1.5.0        | 559.9 MB  | ####5      |  46%
# pytorch-1.5.0        | 559.9 MB  | ####5      |  46%
# pytorch-1.5.0        | 559.9 MB  | ####6      |  46%
# pytorch-1.5.0        | 559.9 MB  | ####6      |  47%
# pytorch-1.5.0        | 559.9 MB  | ####6      |  47%
# pytorch-1.5.0        | 559.9 MB  | ####7      |  47%
# pytorch-1.5.0        | 559.9 MB  | ####7      |  47%
# pytorch-1.5.0        | 559.9 MB  | ####7      |  48%
# pytorch-1.5.0        | 559.9 MB  | ####7      |  48%
# pytorch-1.5.0        | 559.9 MB  | ####8      |  48%
# pytorch-1.5.0        | 559.9 MB  | ####8      |  48%
# pytorch-1.5.0        | 559.9 MB  | ####8      |  49%
# pytorch-1.5.0        | 559.9 MB  | ####8      |  49%
# pytorch-1.5.0        | 559.9 MB  | ####9      |  49%
# pytorch-1.5.0        | 559.9 MB  | ####9      |  49%
# pytorch-1.5.0        | 559.9 MB  | ####9      |  50%
# pytorch-1.5.0        | 559.9 MB  | ####9      |  50%
# pytorch-1.5.0        | 559.9 MB  | #####      |  50%
# pytorch-1.5.0        | 559.9 MB  | #####      |  50%
# pytorch-1.5.0        | 559.9 MB  | #####      |  51%
# pytorch-1.5.0        | 559.9 MB  | #####      |  51%
# pytorch-1.5.0        | 559.9 MB  | #####1     |  51%
# pytorch-1.5.0        | 559.9 MB  | #####1     |  51%
# pytorch-1.5.0        | 559.9 MB  | #####1     |  52%
# pytorch-1.5.0        | 559.9 MB  | #####1     |  52%
# pytorch-1.5.0        | 559.9 MB  | #####2     |  52%
# pytorch-1.5.0        | 559.9 MB  | #####2     |  52%
# pytorch-1.5.0        | 559.9 MB  | #####2     |  53%
# pytorch-1.5.0        | 559.9 MB  | #####2     |  53%
# pytorch-1.5.0        | 559.9 MB  | #####3     |  53%
# pytorch-1.5.0        | 559.9 MB  | #####3     |  53%
# pytorch-1.5.0        | 559.9 MB  | #####3     |  54%
# pytorch-1.5.0        | 559.9 MB  | #####3     |  54%
# pytorch-1.5.0        | 559.9 MB  | #####4     |  54%
# pytorch-1.5.0        | 559.9 MB  | #####4     |  54%
# pytorch-1.5.0        | 559.9 MB  | #####4     |  55%
# pytorch-1.5.0        | 559.9 MB  | #####4     |  55%
# pytorch-1.5.0        | 559.9 MB  | #####5     |  55%
# pytorch-1.5.0        | 559.9 MB  | #####5     |  55%
# pytorch-1.5.0        | 559.9 MB  | #####5     |  56%
# pytorch-1.5.0        | 559.9 MB  | #####5     |  56%
# pytorch-1.5.0        | 559.9 MB  | #####6     |  56%
# pytorch-1.5.0        | 559.9 MB  | #####6     |  56%
# pytorch-1.5.0        | 559.9 MB  | #####6     |  57%
# pytorch-1.5.0        | 559.9 MB  | #####7     |  57%
# pytorch-1.5.0        | 559.9 MB  | #####7     |  57%
# pytorch-1.5.0        | 559.9 MB  | #####7     |  58%
# pytorch-1.5.0        | 559.9 MB  | #####7     |  58%
# pytorch-1.5.0        | 559.9 MB  | #####8     |  58%
# pytorch-1.5.0        | 559.9 MB  | #####8     |  58%
# pytorch-1.5.0        | 559.9 MB  | #####8     |  59%
# pytorch-1.5.0        | 559.9 MB  | #####8     |  59%
# pytorch-1.5.0        | 559.9 MB  | #####9     |  59%
# pytorch-1.5.0        | 559.9 MB  | #####9     |  60%
# pytorch-1.5.0        | 559.9 MB  | ######     |  60%
# pytorch-1.5.0        | 559.9 MB  | ######     |  61%
# pytorch-1.5.0        | 559.9 MB  | ######     |  61%
# pytorch-1.5.0        | 559.9 MB  | ######1    |  61%
# pytorch-1.5.0        | 559.9 MB  | ######1    |  62%
# pytorch-1.5.0        | 559.9 MB  | ######1    |  62%
# pytorch-1.5.0        | 559.9 MB  | ######2    |  62%
# pytorch-1.5.0        | 559.9 MB  | ######2    |  62%
# pytorch-1.5.0        | 559.9 MB  | ######2    |  63%
# pytorch-1.5.0        | 559.9 MB  | ######2    |  63%
# pytorch-1.5.0        | 559.9 MB  | ######3    |  63%
# pytorch-1.5.0        | 559.9 MB  | ######3    |  63%
# pytorch-1.5.0        | 559.9 MB  | ######3    |  64%
# pytorch-1.5.0        | 559.9 MB  | ######3    |  64%
# pytorch-1.5.0        | 559.9 MB  | ######4    |  64%
# pytorch-1.5.0        | 559.9 MB  | ######4    |  64%
# pytorch-1.5.0        | 559.9 MB  | ######4    |  65%
# pytorch-1.5.0        | 559.9 MB  | ######5    |  65%
# pytorch-1.5.0        | 559.9 MB  | ######5    |  65%
# pytorch-1.5.0        | 559.9 MB  | ######5    |  66%
# pytorch-1.5.0        | 559.9 MB  | ######5    |  66%
# pytorch-1.5.0        | 559.9 MB  | ######6    |  66%
# pytorch-1.5.0        | 559.9 MB  | ######6    |  66%
# pytorch-1.5.0        | 559.9 MB  | ######6    |  67%
# pytorch-1.5.0        | 559.9 MB  | ######6    |  67%
# pytorch-1.5.0        | 559.9 MB  | ######7    |  67%
# pytorch-1.5.0        | 559.9 MB  | ######7    |  67%
# pytorch-1.5.0        | 559.9 MB  | ######7    |  68%
# pytorch-1.5.0        | 559.9 MB  | ######7    |  68%
# pytorch-1.5.0        | 559.9 MB  | ######8    |  68%
# pytorch-1.5.0        | 559.9 MB  | ######8    |  68%
# pytorch-1.5.0        | 559.9 MB  | ######8    |  69%
# pytorch-1.5.0        | 559.9 MB  | ######8    |  69%
# pytorch-1.5.0        | 559.9 MB  | ######9    |  69%
# pytorch-1.5.0        | 559.9 MB  | ######9    |  69%
# pytorch-1.5.0        | 559.9 MB  | ######9    |  70%
# pytorch-1.5.0        | 559.9 MB  | ######9    |  70%
# pytorch-1.5.0        | 559.9 MB  | #######    |  70%
# pytorch-1.5.0        | 559.9 MB  | #######    |  70%
# pytorch-1.5.0        | 559.9 MB  | #######    |  71%
# pytorch-1.5.0        | 559.9 MB  | #######    |  71%
# pytorch-1.5.0        | 559.9 MB  | #######1   |  71%
# pytorch-1.5.0        | 559.9 MB  | #######1   |  71%
# pytorch-1.5.0        | 559.9 MB  | #######1   |  72%
# pytorch-1.5.0        | 559.9 MB  | #######1   |  72%
# pytorch-1.5.0        | 559.9 MB  | #######2   |  72%
# pytorch-1.5.0        | 559.9 MB  | #######2   |  72%
# pytorch-1.5.0        | 559.9 MB  | #######2   |  73%
# pytorch-1.5.0        | 559.9 MB  | #######2   |  73%
# pytorch-1.5.0        | 559.9 MB  | #######3   |  73%
# pytorch-1.5.0        | 559.9 MB  | #######3   |  73%
# pytorch-1.5.0        | 559.9 MB  | #######3   |  74%
# pytorch-1.5.0        | 559.9 MB  | #######3   |  74%
# pytorch-1.5.0        | 559.9 MB  | #######4   |  74%
# pytorch-1.5.0        | 559.9 MB  | #######4   |  74%
# pytorch-1.5.0        | 559.9 MB  | #######4   |  75%
# pytorch-1.5.0        | 559.9 MB  | #######4   |  75%
# pytorch-1.5.0        | 559.9 MB  | #######5   |  75%
# pytorch-1.5.0        | 559.9 MB  | #######5   |  75%
# pytorch-1.5.0        | 559.9 MB  | #######5   |  76%
# pytorch-1.5.0        | 559.9 MB  | #######5   |  76%
# pytorch-1.5.0        | 559.9 MB  | #######6   |  76%
# pytorch-1.5.0        | 559.9 MB  | #######6   |  76%
# pytorch-1.5.0        | 559.9 MB  | #######6   |  77%
# pytorch-1.5.0        | 559.9 MB  | #######6   |  77%
# pytorch-1.5.0        | 559.9 MB  | #######7   |  77%
# pytorch-1.5.0        | 559.9 MB  | #######7   |  77%
# pytorch-1.5.0        | 559.9 MB  | #######7   |  78%
# pytorch-1.5.0        | 559.9 MB  | #######8   |  78%
# pytorch-1.5.0        | 559.9 MB  | #######8   |  78%
# pytorch-1.5.0        | 559.9 MB  | #######8   |  79%
# pytorch-1.5.0        | 559.9 MB  | #######8   |  79%
# pytorch-1.5.0        | 559.9 MB  | #######9   |  79%
# pytorch-1.5.0        | 559.9 MB  | #######9   |  79%
# pytorch-1.5.0        | 559.9 MB  | #######9   |  80%
# pytorch-1.5.0        | 559.9 MB  | #######9   |  80%
# pytorch-1.5.0        | 559.9 MB  | ########   |  80%
# pytorch-1.5.0        | 559.9 MB  | ########   |  80%
# pytorch-1.5.0        | 559.9 MB  | ########   |  81%
# pytorch-1.5.0        | 559.9 MB  | ########   |  81%
# pytorch-1.5.0        | 559.9 MB  | ########1  |  81%
# pytorch-1.5.0        | 559.9 MB  | ########1  |  81%
# pytorch-1.5.0        | 559.9 MB  | ########1  |  82%
# pytorch-1.5.0        | 559.9 MB  | ########1  |  82%
# pytorch-1.5.0        | 559.9 MB  | ########2  |  82%
# pytorch-1.5.0        | 559.9 MB  | ########2  |  82%
# pytorch-1.5.0        | 559.9 MB  | ########2  |  83%
# pytorch-1.5.0        | 559.9 MB  | ########2  |  83%
# pytorch-1.5.0        | 559.9 MB  | ########3  |  83%
# pytorch-1.5.0        | 559.9 MB  | ########3  |  83%
# pytorch-1.5.0        | 559.9 MB  | ########3  |  84%
# pytorch-1.5.0        | 559.9 MB  | ########3  |  84%
# pytorch-1.5.0        | 559.9 MB  | ########4  |  84%
# pytorch-1.5.0        | 559.9 MB  | ########4  |  84%
# pytorch-1.5.0        | 559.9 MB  | ########4  |  85%
# pytorch-1.5.0        | 559.9 MB  | ########4  |  85%
# pytorch-1.5.0        | 559.9 MB  | ########5  |  85%
# pytorch-1.5.0        | 559.9 MB  | ########5  |  85%
# pytorch-1.5.0        | 559.9 MB  | ########6  |  86%
# pytorch-1.5.0        | 559.9 MB  | ########6  |  87%
# pytorch-1.5.0        | 559.9 MB  | ########6  |  87%
# pytorch-1.5.0        | 559.9 MB  | ########7  |  87%
# pytorch-1.5.0        | 559.9 MB  | ########7  |  87%
# pytorch-1.5.0        | 559.9 MB  | ########7  |  88%
# pytorch-1.5.0        | 559.9 MB  | ########8  |  88%
# pytorch-1.5.0        | 559.9 MB  | ########8  |  88%
# pytorch-1.5.0        | 559.9 MB  | ########8  |  89%
# pytorch-1.5.0        | 559.9 MB  | ########8  |  89%
# pytorch-1.5.0        | 559.9 MB  | ########9  |  89%
# pytorch-1.5.0        | 559.9 MB  | ########9  |  89%
# pytorch-1.5.0        | 559.9 MB  | ########9  |  90%
# pytorch-1.5.0        | 559.9 MB  | ########9  |  90%
# pytorch-1.5.0        | 559.9 MB  | #########  |  90%
# pytorch-1.5.0        | 559.9 MB  | #########  |  90%
# pytorch-1.5.0        | 559.9 MB  | #########  |  91%
# pytorch-1.5.0        | 559.9 MB  | #########  |  91%
# pytorch-1.5.0        | 559.9 MB  | #########1 |  91%
# pytorch-1.5.0        | 559.9 MB  | #########1 |  91%
# pytorch-1.5.0        | 559.9 MB  | #########1 |  92%
# pytorch-1.5.0        | 559.9 MB  | #########1 |  92%
# pytorch-1.5.0        | 559.9 MB  | #########2 |  92%
# pytorch-1.5.0        | 559.9 MB  | #########2 |  92%
# pytorch-1.5.0        | 559.9 MB  | #########2 |  93%
# pytorch-1.5.0        | 559.9 MB  | #########2 |  93%
# pytorch-1.5.0        | 559.9 MB  | #########3 |  93%
# pytorch-1.5.0        | 559.9 MB  | #########3 |  93%
# pytorch-1.5.0        | 559.9 MB  | #########3 |  94%
# pytorch-1.5.0        | 559.9 MB  | #########3 |  94%
# pytorch-1.5.0        | 559.9 MB  | #########4 |  94%
# pytorch-1.5.0        | 559.9 MB  | #########4 |  94%
# pytorch-1.5.0        | 559.9 MB  | #########4 |  95%
# pytorch-1.5.0        | 559.9 MB  | #########4 |  95%
# pytorch-1.5.0        | 559.9 MB  | #########5 |  95%
# pytorch-1.5.0        | 559.9 MB  | #########5 |  95%
# pytorch-1.5.0        | 559.9 MB  | #########5 |  96%
# pytorch-1.5.0        | 559.9 MB  | #########5 |  96%
# pytorch-1.5.0        | 559.9 MB  | #########6 |  96%
# pytorch-1.5.0        | 559.9 MB  | #########6 |  96%
# pytorch-1.5.0        | 559.9 MB  | #########6 |  97%
# pytorch-1.5.0        | 559.9 MB  | #########6 |  97%
# pytorch-1.5.0        | 559.9 MB  | #########7 |  97%
# pytorch-1.5.0        | 559.9 MB  | #########7 |  98%
# pytorch-1.5.0        | 559.9 MB  | #########7 |  98%
# pytorch-1.5.0        | 559.9 MB  | #########8 |  98%
# pytorch-1.5.0        | 559.9 MB  | #########8 |  98%
# pytorch-1.5.0        | 559.9 MB  | #########8 |  99%
# pytorch-1.5.0        | 559.9 MB  | #########8 |  99%
# pytorch-1.5.0        | 559.9 MB  | #########9 |  99%
# pytorch-1.5.0        | 559.9 MB  | #########9 |  99%
# pytorch-1.5.0        | 559.9 MB  | #########9 | 100%
# pytorch-1.5.0        | 559.9 MB  | #########9 | 100%
# pytorch-1.5.0        | 559.9 MB  | ########## | 100%
#
# openssl-1.1.1g       | 4.8 MB    |            |   0%
# openssl-1.1.1g       | 4.8 MB    | ##4        |  25%
# openssl-1.1.1g       | 4.8 MB    | #####4     |  55%
# openssl-1.1.1g       | 4.8 MB    | ########4  |  84%
# openssl-1.1.1g       | 4.8 MB    | ########## | 100%
#
# cudatoolkit-10.2.89  | 317.2 MB  |            |   0%
# cudatoolkit-10.2.89  | 317.2 MB  |            |   0%
# cudatoolkit-10.2.89  | 317.2 MB  |            |   1%
# cudatoolkit-10.2.89  | 317.2 MB  | 1          |   1%
# cudatoolkit-10.2.89  | 317.2 MB  | 1          |   2%
# cudatoolkit-10.2.89  | 317.2 MB  | 2          |   2%
# cudatoolkit-10.2.89  | 317.2 MB  | 2          |   2%
# cudatoolkit-10.2.89  | 317.2 MB  | 2          |   3%
# cudatoolkit-10.2.89  | 317.2 MB  | 3          |   3%
# cudatoolkit-10.2.89  | 317.2 MB  | 3          |   4%
# cudatoolkit-10.2.89  | 317.2 MB  | 4          |   4%
# cudatoolkit-10.2.89  | 317.2 MB  | 4          |   5%
# cudatoolkit-10.2.89  | 317.2 MB  | 5          |   5%
# cudatoolkit-10.2.89  | 317.2 MB  | 5          |   6%
# cudatoolkit-10.2.89  | 317.2 MB  | 6          |   6%
# cudatoolkit-10.2.89  | 317.2 MB  | 6          |   7%
# cudatoolkit-10.2.89  | 317.2 MB  | 6          |   7%
# cudatoolkit-10.2.89  | 317.2 MB  | 7          |   7%
# cudatoolkit-10.2.89  | 317.2 MB  | 7          |   8%
# cudatoolkit-10.2.89  | 317.2 MB  | 8          |   8%
# cudatoolkit-10.2.89  | 317.2 MB  | 8          |   9%
# cudatoolkit-10.2.89  | 317.2 MB  | 9          |   9%
# cudatoolkit-10.2.89  | 317.2 MB  | 9          |  10%
# cudatoolkit-10.2.89  | 317.2 MB  | #          |  10%
# cudatoolkit-10.2.89  | 317.2 MB  | #          |  11%
# cudatoolkit-10.2.89  | 317.2 MB  | #1         |  11%
# cudatoolkit-10.2.89  | 317.2 MB  | #1         |  12%
# cudatoolkit-10.2.89  | 317.2 MB  | #2         |  12%
# cudatoolkit-10.2.89  | 317.2 MB  | #2         |  12%
# cudatoolkit-10.2.89  | 317.2 MB  | #2         |  13%
# cudatoolkit-10.2.89  | 317.2 MB  | #3         |  13%
# cudatoolkit-10.2.89  | 317.2 MB  | #3         |  14%
# cudatoolkit-10.2.89  | 317.2 MB  | #4         |  14%
# cudatoolkit-10.2.89  | 317.2 MB  | #4         |  15%
# cudatoolkit-10.2.89  | 317.2 MB  | #5         |  15%
# cudatoolkit-10.2.89  | 317.2 MB  | #5         |  16%
# cudatoolkit-10.2.89  | 317.2 MB  | #6         |  16%
# cudatoolkit-10.2.89  | 317.2 MB  | #6         |  17%
# cudatoolkit-10.2.89  | 317.2 MB  | #7         |  17%
# cudatoolkit-10.2.89  | 317.2 MB  | #7         |  18%
# cudatoolkit-10.2.89  | 317.2 MB  | #8         |  18%
# cudatoolkit-10.2.89  | 317.2 MB  | #8         |  18%
# cudatoolkit-10.2.89  | 317.2 MB  | #8         |  19%
# cudatoolkit-10.2.89  | 317.2 MB  | #9         |  19%
# cudatoolkit-10.2.89  | 317.2 MB  | #9         |  20%
# cudatoolkit-10.2.89  | 317.2 MB  | ##         |  20%
# cudatoolkit-10.2.89  | 317.2 MB  | ##         |  21%
# cudatoolkit-10.2.89  | 317.2 MB  | ##1        |  21%
# cudatoolkit-10.2.89  | 317.2 MB  | ##1        |  22%
# cudatoolkit-10.2.89  | 317.2 MB  | ##2        |  22%
# cudatoolkit-10.2.89  | 317.2 MB  | ##2        |  23%
# cudatoolkit-10.2.89  | 317.2 MB  | ##3        |  23%
# cudatoolkit-10.2.89  | 317.2 MB  | ##3        |  23%
# cudatoolkit-10.2.89  | 317.2 MB  | ##3        |  24%
# cudatoolkit-10.2.89  | 317.2 MB  | ##4        |  24%
# cudatoolkit-10.2.89  | 317.2 MB  | ##4        |  25%
# cudatoolkit-10.2.89  | 317.2 MB  | ##5        |  25%
# cudatoolkit-10.2.89  | 317.2 MB  | ##5        |  26%
# cudatoolkit-10.2.89  | 317.2 MB  | ##6        |  26%
# cudatoolkit-10.2.89  | 317.2 MB  | ##6        |  27%
# cudatoolkit-10.2.89  | 317.2 MB  | ##7        |  27%
# cudatoolkit-10.2.89  | 317.2 MB  | ##7        |  28%
# cudatoolkit-10.2.89  | 317.2 MB  | ##8        |  28%
# cudatoolkit-10.2.89  | 317.2 MB  | ##8        |  28%
# cudatoolkit-10.2.89  | 317.2 MB  | ##8        |  29%
# cudatoolkit-10.2.89  | 317.2 MB  | ##9        |  29%
# cudatoolkit-10.2.89  | 317.2 MB  | ##9        |  30%
# cudatoolkit-10.2.89  | 317.2 MB  | ###        |  30%
# cudatoolkit-10.2.89  | 317.2 MB  | ###        |  31%
# cudatoolkit-10.2.89  | 317.2 MB  | ###1       |  31%
# cudatoolkit-10.2.89  | 317.2 MB  | ###1       |  32%
# cudatoolkit-10.2.89  | 317.2 MB  | ###2       |  32%
# cudatoolkit-10.2.89  | 317.2 MB  | ###2       |  33%
# cudatoolkit-10.2.89  | 317.2 MB  | ###3       |  33%
# cudatoolkit-10.2.89  | 317.2 MB  | ###3       |  33%
# cudatoolkit-10.2.89  | 317.2 MB  | ###3       |  34%
# cudatoolkit-10.2.89  | 317.2 MB  | ###4       |  34%
# cudatoolkit-10.2.89  | 317.2 MB  | ###4       |  35%
# cudatoolkit-10.2.89  | 317.2 MB  | ###5       |  35%
# cudatoolkit-10.2.89  | 317.2 MB  | ###5       |  36%
# cudatoolkit-10.2.89  | 317.2 MB  | ###6       |  36%
# cudatoolkit-10.2.89  | 317.2 MB  | ###6       |  37%
# cudatoolkit-10.2.89  | 317.2 MB  | ###7       |  37%
# cudatoolkit-10.2.89  | 317.2 MB  | ###7       |  38%
# cudatoolkit-10.2.89  | 317.2 MB  | ###7       |  38%
# cudatoolkit-10.2.89  | 317.2 MB  | ###8       |  38%
# cudatoolkit-10.2.89  | 317.2 MB  | ###8       |  39%
# cudatoolkit-10.2.89  | 317.2 MB  | ###9       |  39%
# cudatoolkit-10.2.89  | 317.2 MB  | ###9       |  40%
# cudatoolkit-10.2.89  | 317.2 MB  | ####       |  40%
# cudatoolkit-10.2.89  | 317.2 MB  | ####       |  41%
# cudatoolkit-10.2.89  | 317.2 MB  | ####1      |  41%
# cudatoolkit-10.2.89  | 317.2 MB  | ####1      |  42%
# cudatoolkit-10.2.89  | 317.2 MB  | ####2      |  42%
# cudatoolkit-10.2.89  | 317.2 MB  | ####2      |  42%
# cudatoolkit-10.2.89  | 317.2 MB  | ####2      |  43%
# cudatoolkit-10.2.89  | 317.2 MB  | ####3      |  43%
# cudatoolkit-10.2.89  | 317.2 MB  | ####3      |  44%
# cudatoolkit-10.2.89  | 317.2 MB  | ####4      |  44%
# cudatoolkit-10.2.89  | 317.2 MB  | ####4      |  45%
# cudatoolkit-10.2.89  | 317.2 MB  | ####5      |  45%
# cudatoolkit-10.2.89  | 317.2 MB  | ####5      |  46%
# cudatoolkit-10.2.89  | 317.2 MB  | ####5      |  46%
# cudatoolkit-10.2.89  | 317.2 MB  | ####6      |  46%
# cudatoolkit-10.2.89  | 317.2 MB  | ####6      |  47%
# cudatoolkit-10.2.89  | 317.2 MB  | ####7      |  47%
# cudatoolkit-10.2.89  | 317.2 MB  | ####7      |  48%
# cudatoolkit-10.2.89  | 317.2 MB  | ####8      |  48%
# cudatoolkit-10.2.89  | 317.2 MB  | ####8      |  49%
# cudatoolkit-10.2.89  | 317.2 MB  | ####9      |  49%
# cudatoolkit-10.2.89  | 317.2 MB  | ####9      |  50%
# cudatoolkit-10.2.89  | 317.2 MB  | #####      |  50%
# cudatoolkit-10.2.89  | 317.2 MB  | #####      |  51%
# cudatoolkit-10.2.89  | 317.2 MB  | #####      |  51%
# cudatoolkit-10.2.89  | 317.2 MB  | #####1     |  51%
# cudatoolkit-10.2.89  | 317.2 MB  | #####1     |  52%
# cudatoolkit-10.2.89  | 317.2 MB  | #####2     |  52%
# cudatoolkit-10.2.89  | 317.2 MB  | #####2     |  53%
# cudatoolkit-10.2.89  | 317.2 MB  | #####3     |  53%
# cudatoolkit-10.2.89  | 317.2 MB  | #####3     |  54%
# cudatoolkit-10.2.89  | 317.2 MB  | #####4     |  54%
# cudatoolkit-10.2.89  | 317.2 MB  | #####4     |  55%
# cudatoolkit-10.2.89  | 317.2 MB  | #####5     |  55%
# cudatoolkit-10.2.89  | 317.2 MB  | #####5     |  56%
# cudatoolkit-10.2.89  | 317.2 MB  | #####5     |  56%
# cudatoolkit-10.2.89  | 317.2 MB  | #####6     |  56%
# cudatoolkit-10.2.89  | 317.2 MB  | #####6     |  57%
# cudatoolkit-10.2.89  | 317.2 MB  | #####7     |  57%
# cudatoolkit-10.2.89  | 317.2 MB  | #####7     |  58%
# cudatoolkit-10.2.89  | 317.2 MB  | #####8     |  58%
# cudatoolkit-10.2.89  | 317.2 MB  | #####8     |  59%
# cudatoolkit-10.2.89  | 317.2 MB  | #####9     |  59%
# cudatoolkit-10.2.89  | 317.2 MB  | #####9     |  60%
# cudatoolkit-10.2.89  | 317.2 MB  | ######     |  60%
# cudatoolkit-10.2.89  | 317.2 MB  | ######     |  60%
# cudatoolkit-10.2.89  | 317.2 MB  | ######     |  61%
# cudatoolkit-10.2.89  | 317.2 MB  | ######1    |  61%
# cudatoolkit-10.2.89  | 317.2 MB  | ######1    |  62%
# cudatoolkit-10.2.89  | 317.2 MB  | ######2    |  62%
# cudatoolkit-10.2.89  | 317.2 MB  | ######2    |  63%
# cudatoolkit-10.2.89  | 317.2 MB  | ######3    |  63%
# cudatoolkit-10.2.89  | 317.2 MB  | ######3    |  64%
# cudatoolkit-10.2.89  | 317.2 MB  | ######4    |  64%
# cudatoolkit-10.2.89  | 317.2 MB  | ######4    |  65%
# cudatoolkit-10.2.89  | 317.2 MB  | ######5    |  65%
# cudatoolkit-10.2.89  | 317.2 MB  | ######5    |  65%
# cudatoolkit-10.2.89  | 317.2 MB  | ######5    |  66%
# cudatoolkit-10.2.89  | 317.2 MB  | ######6    |  66%
# cudatoolkit-10.2.89  | 317.2 MB  | ######6    |  67%
# cudatoolkit-10.2.89  | 317.2 MB  | ######7    |  67%
# cudatoolkit-10.2.89  | 317.2 MB  | ######7    |  68%
# cudatoolkit-10.2.89  | 317.2 MB  | ######8    |  68%
# cudatoolkit-10.2.89  | 317.2 MB  | ######8    |  69%
# cudatoolkit-10.2.89  | 317.2 MB  | ######9    |  69%
# cudatoolkit-10.2.89  | 317.2 MB  | ######9    |  70%
# cudatoolkit-10.2.89  | 317.2 MB  | #######    |  70%
# cudatoolkit-10.2.89  | 317.2 MB  | #######    |  70%
# cudatoolkit-10.2.89  | 317.2 MB  | #######    |  71%
# cudatoolkit-10.2.89  | 317.2 MB  | #######1   |  71%
# cudatoolkit-10.2.89  | 317.2 MB  | #######1   |  72%
# cudatoolkit-10.2.89  | 317.2 MB  | #######2   |  72%
# cudatoolkit-10.2.89  | 317.2 MB  | #######2   |  73%
# cudatoolkit-10.2.89  | 317.2 MB  | #######3   |  73%
# cudatoolkit-10.2.89  | 317.2 MB  | #######3   |  74%
# cudatoolkit-10.2.89  | 317.2 MB  | #######4   |  74%
# cudatoolkit-10.2.89  | 317.2 MB  | #######4   |  75%
# cudatoolkit-10.2.89  | 317.2 MB  | #######5   |  75%
# cudatoolkit-10.2.89  | 317.2 MB  | #######5   |  75%
# cudatoolkit-10.2.89  | 317.2 MB  | #######5   |  76%
# cudatoolkit-10.2.89  | 317.2 MB  | #######6   |  76%
# cudatoolkit-10.2.89  | 317.2 MB  | #######6   |  77%
# cudatoolkit-10.2.89  | 317.2 MB  | #######7   |  77%
# cudatoolkit-10.2.89  | 317.2 MB  | #######7   |  78%
# cudatoolkit-10.2.89  | 317.2 MB  | #######8   |  78%
# cudatoolkit-10.2.89  | 317.2 MB  | #######8   |  79%
# cudatoolkit-10.2.89  | 317.2 MB  | #######9   |  79%
# cudatoolkit-10.2.89  | 317.2 MB  | #######9   |  79%
# cudatoolkit-10.2.89  | 317.2 MB  | #######9   |  80%
# cudatoolkit-10.2.89  | 317.2 MB  | ########   |  80%
# cudatoolkit-10.2.89  | 317.2 MB  | ########   |  81%
# cudatoolkit-10.2.89  | 317.2 MB  | ########1  |  81%
# cudatoolkit-10.2.89  | 317.2 MB  | ########1  |  82%
# cudatoolkit-10.2.89  | 317.2 MB  | ########2  |  82%
# cudatoolkit-10.2.89  | 317.2 MB  | ########2  |  83%
# cudatoolkit-10.2.89  | 317.2 MB  | ########3  |  83%
# cudatoolkit-10.2.89  | 317.2 MB  | ########3  |  84%
# cudatoolkit-10.2.89  | 317.2 MB  | ########3  |  84%
# cudatoolkit-10.2.89  | 317.2 MB  | ########4  |  84%
# cudatoolkit-10.2.89  | 317.2 MB  | ########4  |  85%
# cudatoolkit-10.2.89  | 317.2 MB  | ########5  |  85%
# cudatoolkit-10.2.89  | 317.2 MB  | ########5  |  86%
# cudatoolkit-10.2.89  | 317.2 MB  | ########6  |  86%
# cudatoolkit-10.2.89  | 317.2 MB  | ########6  |  87%
# cudatoolkit-10.2.89  | 317.2 MB  | ########7  |  87%
# cudatoolkit-10.2.89  | 317.2 MB  | ########7  |  88%
# cudatoolkit-10.2.89  | 317.2 MB  | ########8  |  88%
# cudatoolkit-10.2.89  | 317.2 MB  | ########8  |  89%
# cudatoolkit-10.2.89  | 317.2 MB  | ########9  |  89%
# cudatoolkit-10.2.89  | 317.2 MB  | ########9  |  89%
# cudatoolkit-10.2.89  | 317.2 MB  | ########9  |  90%
# cudatoolkit-10.2.89  | 317.2 MB  | #########  |  90%
# cudatoolkit-10.2.89  | 317.2 MB  | #########  |  91%
# cudatoolkit-10.2.89  | 317.2 MB  | #########1 |  91%
# cudatoolkit-10.2.89  | 317.2 MB  | #########1 |  92%
# cudatoolkit-10.2.89  | 317.2 MB  | #########2 |  92%
# cudatoolkit-10.2.89  | 317.2 MB  | #########2 |  93%
# cudatoolkit-10.2.89  | 317.2 MB  | #########3 |  93%
# cudatoolkit-10.2.89  | 317.2 MB  | #########3 |  94%
# cudatoolkit-10.2.89  | 317.2 MB  | #########4 |  94%
# cudatoolkit-10.2.89  | 317.2 MB  | #########4 |  94%
# cudatoolkit-10.2.89  | 317.2 MB  | #########4 |  95%
# cudatoolkit-10.2.89  | 317.2 MB  | #########5 |  95%
# cudatoolkit-10.2.89  | 317.2 MB  | #########5 |  96%
# cudatoolkit-10.2.89  | 317.2 MB  | #########6 |  96%
# cudatoolkit-10.2.89  | 317.2 MB  | #########6 |  97%
# cudatoolkit-10.2.89  | 317.2 MB  | #########7 |  97%
# cudatoolkit-10.2.89  | 317.2 MB  | #########7 |  98%
# cudatoolkit-10.2.89  | 317.2 MB  | #########8 |  98%
# cudatoolkit-10.2.89  | 317.2 MB  | #########8 |  99%
# cudatoolkit-10.2.89  | 317.2 MB  | #########9 |  99%
# cudatoolkit-10.2.89  | 317.2 MB  | #########9 | 100%
# cudatoolkit-10.2.89  | 317.2 MB  | #########9 | 100%
# cudatoolkit-10.2.89  | 317.2 MB  | ########## | 100%
#
# ninja-1.9.0          | 238 KB    |            |   0%
# ninja-1.9.0          | 238 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# use y as your prediction target:

y = np.array([0,0,0,1,1,1,1]).reshape(-1, 1)

import torch
import torch.nn.functional as F

def train(V, y, components, epochs):
    try:
        V = V.toarray()
    except AttributeError:
        pass

    Y = torch.tensor(y, dtype=torch.float32)
    X = torch.tensor(V, dtype=torch.float32)

    C = torch.tensor(components, dtype=torch.float32, requires_grad=True)
    beta = torch.randn((components.shape[0], 1), requires_grad=True)

    opt = torch.optim.Adam([C, beta], lr=0.01)
    criterion = torch.nn.BCELoss()

    for i in range(epochs):
        L = torch.mm(X, C.T)
        out = torch.mm(L, beta)
        p = torch.sigmoid(out)
        loss = criterion(p, Y)

        if i % 20 == 0:
            print(loss)

        loss.backward()
        opt.step()
        opt.zero_grad()

    return C.detach().numpy()


learned_vecs = train(v, y, word_vecs.T, 200)
plot_words(learned_vecs.T, labels)
# Out:
# tensor(1.3238, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.5985, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.2346, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.0899, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.0422, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.0245, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.0164, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.0119, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.0091, grad_fn=<BinaryCrossEntropyBackward>)
# tensor(0.0072, grad_fn=<BinaryCrossEntropyBackward>)

# %%
YouTubeVideo('YYdQhbnbqsw', width=640,height=360)

# %% [markdown]
# **Assignment**
#
# The assignment is related to Word2Vec! Feel free to complete it now :)

# %%
YouTubeVideo('h6J1-SB_Bno', width=640,height=360)

# %% [markdown]
# **Exercise 3**
# Let's take a look at how PCA is reconstructing the cooccurrence matrix of the terms within documents.
#
# Plot a heatmap of $X^TX$ and a heatmap of $ww^T$ where $w$ is is learned mapping of from word space into the reduced dimensional space of the PCA (i.e. $w = V^T$ from the SVD decomposition of hte $X$ matrix)
#
# Does the two matrices seem qualitatively similar, from their heatmaps?

# %%
def plot_heatmap(d, labels):
    d = pd.DataFrame(d, index=labels, columns=labels)
    sns.heatmap(d)

plot_heatmap(v.T@v, labels)

plot_heatmap(word_vecs@word_vecs.T, labels)

# %% [markdown]
# **Exercise 4**
#
# Let's try and reconstuct a cooccurrence matrix that takes word position into account. You can think of this as a simplified version of GloVe! We will see if the embeddings differ qualitatively.
#
# First, create a coccurrence matrix where the value of i,j is incremented by $1/D$ (where $D$ is the distance between two words) every time two words cooccurr in the same document. Plot it out in a heatmap, compare it to the previous two heatmaps. How does it differ?
#
# Second, learn a new 2-dimensional word embedding, $w$, that minimizes the frobenius norm of the distance between the target matrix (the cooccurrence matrix you constructed) and the matrix $ww^T$. Use pytorch to optimize the problem.
#
# Third, plot your learned 2-dimensional word embeddings. How do they compare to the other embeddings?
